# %% [markdown]
# # Day 4 - Block 4: Playwright And TypeScript Revision
#
# Use `Reference Files/block4_playwright_typescript_revision.py` offline.
#
# Practice answers:
# - Why Playwright?
# - What is browser context?
# - Locator vs selector.
# - How do you handle auth/session reuse?
# - How do you debug flaky tests?
# - Why TypeScript for Playwright?
# - What should be UI vs API?
