# %% [markdown]
# # Day 4 - Block 5: AI Metrics And Dashboard Diagnosis
#
# Use `Reference Files/block5_ai_metrics_dashboard_diagnosis.py` offline.
#
# Practice:
# - Calculate context precision and recall.
# - Diagnose low precision vs low recall.
# - Explain faithfulness vs groundedness.
# - Calculate guardrail precision/recall.
# - Diagnose retrieval vs generation vs tool vs schema issue.
# - Explain LangSmith vs RAGAS.
