# %% [markdown]
# # Day 4 - Block 2: Python OOPs And Automation Design
#
# Use `Reference Files/block2_python_oops_automation_design.py` offline.
#
# Practice:
# - Write `TestResult` class.
# - Write `User` class with `__repr__` and `__eq__`.
# - Write `BaseApiClient` and `CustomerApiClient`.
# - Write `BasePage` / `LoginPage` skeleton.
# - Write retry decorator.
# - Explain every class in interview language.
