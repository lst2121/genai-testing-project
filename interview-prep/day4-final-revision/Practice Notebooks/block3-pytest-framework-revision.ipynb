# %% [markdown]
# # Day 4 - Block 3: Pytest Framework Revision
#
# Use `Reference Files/block3_pytest_framework_revision.py` offline.
#
# Practice:
# - Write one fixture.
# - Write one parametrized test.
# - Write one `pytest.raises` test.
# - Explain fixture scopes.
# - Explain `conftest.py`.
# - Explain PR gate vs nightly tests.
