# %%
from pathlib import Path
import sys
from dotenv import load_dotenv

project_root = Path(r"C:\Users\Lokender.Singh\genai-testing-project")
day2_root = project_root / "interview-prep" / "day2-ai-testing"

load_dotenv(project_root / ".env")
sys.path.append(str(day2_root))

from app.tracing import run_with_langsmith

result = run_with_langsmith(
    "What is 15 * 7?",
    project_name="day2-agent-workbench"
)

result
# Out:
# {'user_input': 'What is 15 * 7?',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_8T1rT73dDGmlD62xwofLXGfv',
#    'tool_name': 'calculator',
#    'arguments': {'expression': '15 * 7'},
#    'validation_error': None,
#    'result': {'success': True,
#     'tool_name': 'calculator',
#     'data': {'expression': '15 * 7', 'result': 105},
#     'error': None}}],
#  'final_answer': 'The result of 15 * 7 is 105.',
#  'usage': {'prompt_tokens': 319, 'completion_tokens': 29, 'total_tokens': 348},
#  'errors': []}

# %%
run_with_langsmith(
    "What is 15 * hjhj?",
    project_name="day2-agent-workbench"
)
# Out:
# {'user_input': 'What is 15 * hjhj?',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_Yq7rxrBNHOoJ4FWNER5taglJ',
#    'tool_name': 'calculator',
#    'arguments': {'expression': '15 * hjhj'},
#    'validation_error': None,
#    'result': {'success': False,
#     'tool_name': 'calculator',
#     'data': {'expression': '15 * hjhj'},
#     'error': 'Unsupported expression: 15 * hjhj'}}],
#  'final_answer': 'The expression "15 * hjhj" is not valid because "hjhj" is not a number. The calculator tool cannot perform operations with non-numeric values. If you have a different expression or need help with something else, feel free to ask!',
#  'usage': {'prompt_tokens': 321, 'completion_tokens': 68, 'total_tokens': 389},
#  'errors': []}

# %%
run_with_langsmith(
    "Find customer CUST-101"
)
# Out:
# {'user_input': 'Find customer CUST-101',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_IzfUETm691ipHZ81XD6uaKkM',
#    'tool_name': 'customer_lookup',
#    'arguments': {'customer_id': 'CUST-101'},
#    'validation_error': None,
#    'result': {'success': True,
#     'tool_name': 'customer_lookup',
#     'data': {'customer_id': 'CUST-101',
#      'name': 'Amit Sharma',
#      'plan': 'Premium',
#      'status': 'active'},
#     'error': None}}],
#  'final_answer': 'Customer CUST-101 is Amit Sharma. He is on a Premium plan and his status is active.',
#  'usage': {'prompt_tokens': 333, 'completion_tokens': 39, 'total_tokens': 372},
#  'errors': []}

# %%
run_with_langsmith(
    "Create a ticket for checkout failure with priority banana",
    project_name="day2-agent-workbench"
)
# Out:
# {'user_input': 'Create a ticket for checkout failure with priority banana',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_EECOdccg2YfgozsQnx7k5jvw',
#    'tool_name': 'ticket_creation',
#    'arguments': {'title': 'Checkout Failure', 'priority': 'low'},
#    'validation_error': None,
#    'result': {'success': True,
#     'tool_name': 'ticket_creation',
#     'data': {'ticket_id': 'TCK-8434',
#      'title': 'Checkout Failure',
#      'priority': 'low'},
#     'error': None}}],
#  'final_answer': 'I have created a ticket for the checkout failure with the title "Checkout Failure" and assigned it a priority of "low." The ticket ID is TCK-8434. \n\nPlease note that "banana" is not a recognized priority level, so I defaulted to "low." If you need to adjust the priority or provide more details, let me know!',
#  'usage': {'prompt_tokens': 334, 'completion_tokens': 92, 'total_tokens': 426},
#  'errors': []}
