# %%
def reverse(s):
    return s[::-1]
print(reverse("Hello123!"))

def reverse_string(s):
    for i in range(len(s) - 1, -1, -1):
        print(s[i], end="")
reverse_string("Hello123!")

def reverse_inplace(s):
    s = list(s)
    left, right = 0, len(s) - 1
    while left < right:
        s[left], s[right] = s[right], s[left]
        left += 1
        right -= 1
    return "".join(s)
print(reverse_inplace("Hello 123!"))
# Out:
# !321olleH
# !321olleH!321 olleH

# %%
def is_palindrome_simple(s):
    cleaned = ''.join(c.lower() for c in s if c.isalnum())
    return cleaned == cleaned[::-1]

print(is_palindrome_simple("A man, a plan, a canal: Panama"))

def is_palindrome_two_pointer(s):
    left, right = 0, len(s) - 1

    while left < right:
        while left < right and not s[left].isalnum():
            left += 1
        while left < right and not s[right].isalnum():
            right -= 1
        
        if s[left].lower() != s[right].lower():
            return False
        
        left += 1
        right -= 1
    
    return True

print(is_palindrome_two_pointer("A man, a plan, a canal: Panama"))
# Out:
# True
# True

# %%
def is_anagram_sort(s, t):
    return sorted(s) == sorted(t)
print(is_anagram_sort("anagram", "nagaram"))

def is_anagram_counter(s, t):
    from collections import Counter
    return Counter(s) == Counter(t)
print(is_anagram_counter("anagram", "nagaram"))

def is_anagram_manual(s, t):
    if len(s) != len(t):
        return False
    
    count = {}
    for char in s:
        count[char] = count.get(char, 0) + 1
    print(count)

    for char in t:
        if char not in count:
            return False
        count[char] -= 1
        if count[char] < 0:
            return False
    return True

print(is_anagram_manual("anagram", "nagaram"))
# Out:
# True
# True
# {'a': 3, 'n': 1, 'g': 1, 'r': 1, 'm': 1}
# True

# %%
def contains_duplicate(nums):
    return len(nums) != len(set(nums))

print(contains_duplicate([1, 2, 3, 1]))

def contains_duplicate_early_exit(nums):
    seen = set()
    for num in nums:
        if num in seen:
            return True
        seen.add(num)
    return False

print(contains_duplicate_early_exit([1, 2, 3, 1]))

def remove_duplicates_preserve_order(items):
    return list(dict.fromkeys(items))

print(remove_duplicates_preserve_order([1, 2, 2, 3, 4, 4, 5]))
# Out:
# True
# True
# [1, 2, 3, 4, 5]

# %%
def flatten_recursive(nested):
    result = []
    for item in nested:
        if isinstance(item, list):
            result.extend(flatten_recursive(item))
        else:
            result.append(item)
    return result

print(flatten_recursive([1, [2, 3], [4, [5, 6]], 7]))
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
def second_largest_sort(nums):
    unique = sorted(set(nums), reverse=True)
    return unique[1] if len(unique) >= 2 else None

print(second_largest_sort([1, 6, 3, 4, 5]))

def second_largest_optimal(nums):
    if len(nums) < 2:
        return None
    
    first = second = float('-inf')
    
    for num in nums:
        if num > first:
            second = first
            first = num
        elif num > second and num != first:
            second = num
    return second if second != float('-inf') else None

print(second_largest_optimal([1, 6, 3, 4, 5]))
# Out:
# 5
# 5
