# %%
from pathlib import Path
import sys

project_root = Path.cwd()
while project_root.name != "genai-testing-project":
    project_root = project_root.parent

day2_root = project_root / "interview-prep" / "day2-ai-testing"
sys.path.append(str(day2_root))

from app.simple_agent import run_openai_tool_agent

# %%
result = run_openai_tool_agent("What is 15 * 7?")
result.to_dict()
# Out:
# {'user_input': 'What is 15 * 7?',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_yRurihlkl88XVdXaV2MBvn3y',
#    'tool_name': 'calculator',
#    'arguments': {'expression': '15 * 7'},
#    'validation_error': None,
#    'result': {'success': True,
#     'tool_name': 'calculator',
#     'data': {'expression': '15 * 7', 'result': 105},
#     'error': None}}],
#  'final_answer': 'The result of 15 * 7 is 105.',
#  'usage': {'prompt_tokens': 319, 'completion_tokens': 29, 'total_tokens': 348},
#  'errors': []}

# %%
result = run_openai_tool_agent("What is 15 * hjhj?")
result.to_dict()
# Out:
# {'user_input': 'What is 15 * hjhj?',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_KvZRnGtZ6yojLRDRXQLR5zVK',
#    'tool_name': 'calculator',
#    'arguments': {'expression': '15 * hjhj'},
#    'validation_error': None,
#    'result': {'success': False,
#     'tool_name': 'calculator',
#     'data': {'expression': '15 * hjhj'},
#     'error': 'Unsupported expression: 15 * hjhj'}}],
#  'final_answer': 'The expression "15 * hjhj" is unsupported because "hjhj" is not a valid number. The calculator tool can only perform operations with numerical values. If you have a specific number to replace "hjhj," I can help you calculate that.',
#  'usage': {'prompt_tokens': 321, 'completion_tokens': 68, 'total_tokens': 389},
#  'errors': []}

# %%
result = run_openai_tool_agent("Find customer CUST-101")
result.to_dict()
# Out:
# {'user_input': 'Find customer CUST-101',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_QSWzpDVPfAdoHw95knAoqMGP',
#    'tool_name': 'customer_lookup',
#    'arguments': {'customer_id': 'CUST-101'},
#    'validation_error': None,
#    'result': {'success': True,
#     'tool_name': 'customer_lookup',
#     'data': {'customer_id': 'CUST-101',
#      'name': 'Amit Sharma',
#      'plan': 'Premium',
#      'status': 'active'},
#     'error': None}}],
#  'final_answer': 'Customer CUST-101 is Amit Sharma. He is on a Premium plan and his status is active.',
#  'usage': {'prompt_tokens': 333, 'completion_tokens': 39, 'total_tokens': 372},
#  'errors': []}

# %%
result = run_openai_tool_agent("Find customer CUST-999")
result.to_dict()
# Out:
# {'user_input': 'Find customer CUST-999',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_hn6WtBdBdRlF2gVQ3J6ljF69',
#    'tool_name': 'customer_lookup',
#    'arguments': {'customer_id': 'CUST-999'},
#    'validation_error': None,
#    'result': {'success': False,
#     'tool_name': 'customer_lookup',
#     'data': {'customer_id': 'CUST-999'},
#     'error': 'Customer not found'}}],
#  'final_answer': 'I attempted to find customer CUST-999, but the lookup returned an error indicating that the customer was not found. Please check the customer ID for accuracy or provide a different ID to search for.',
#  'usage': {'prompt_tokens': 316, 'completion_tokens': 58, 'total_tokens': 374},
#  'errors': []}

# %%
result = run_openai_tool_agent(
        "Create a high priority ticket for checkout failure"
    )
result.to_dict()
# Out:
# {'user_input': 'Create a high priority ticket for checkout failure',
#  'model': 'gpt-4o-mini',
#  'first_model_message': None,
#  'tool_calls': [{'tool_call_id': 'call_pRjqb9UHL81ZFUr7bOqe0o4C',
#    'tool_name': 'ticket_creation',
#    'arguments': {'title': 'Checkout Failure', 'priority': 'high'},
#    'validation_error': None,
#    'result': {'success': True,
#     'tool_name': 'ticket_creation',
#     'data': {'ticket_id': 'TCK-8326',
#      'title': 'Checkout Failure',
#      'priority': 'high'},
#     'error': None}}],
#  'final_answer': 'A high-priority ticket for the checkout failure has been successfully created. Here are the details:\n\n- **Ticket ID:** TCK-8326\n- **Title:** Checkout Failure\n- **Priority:** High\n\nIf you need any further assistance, feel free to ask!',
#  'usage': {'prompt_tokens': 332, 'completion_tokens': 74, 'total_tokens': 406},
#  'errors': []}

# %%
result = run_openai_tool_agent("Say hello in one short sentence")
result.to_dict()
# Out:
# {'user_input': 'Say hello in one short sentence',
#  'model': 'gpt-4o-mini',
#  'first_model_message': 'Hello! How can I assist you today?',
#  'tool_calls': [],
#  'final_answer': 'Hello! How can I assist you today?',
#  'usage': {'prompt_tokens': 203, 'completion_tokens': 10, 'total_tokens': 213},
#  'errors': []}
